# %%
from wand.image import Image
from PIL import Image as PI
import pyocr
import pyocr.builders
import io

# %%
tool = pyocr.get_available_tools()[0]
lang = tool.get_available_languages()[1]

# %%
lang
# Out:
# 'osd'

# %%
req_image = []
final_text = []

# %%
image_pdf = Image(filename="/home/dinesh/Downloads/Passport_selfAttested.pdf", resolution=300)
image_jpeg = image_pdf.convert('jpeg')

# %%
for img in image_jpeg.sequence:
    img_page = Image(image=img)
    req_image.append(img_page.make_blob('jpeg'))

# %%
for img in req_image: 
    txt = tool.image_to_string(
        PI.open(io.BytesIO(img)),
        lang=lang,
        builder=pyocr.builders.TextBuilder()
    )
    final_text.append(txt)

# %%
final_text
# Out:
# ['脚 伽赖柄\n\n \n\n \n\nشا مةسلالعا\n\nmp\n\nп пиsءип\n\nппин സപ тл ร شاد وسةغاعدرسملد\n\n夏 ধفロبيةلدئد\n\nधानधारी nspmsch 05غا エ围ｺｪ且\n\nsrರೆיהп rrpo ণغامرس dm п لخالعامرلعاعدغا ะяаপدпది لعالا runmaru لعا\n\nр ين0\n\nnn धरmधानνenغاक्षणةп\n\nلعاｪп岂sи\n\n酬 pggenmp nn प لالاف\n\nغالعاوغالا п\n\nधानउएनअल لشا np क्षाกوన్غا\n\nదిثاdఎ뽑ది己己rp مهلعاللاثا రా覆దిర్క\n\nг لعاد ㄱ вмюцспв ㅁ لعا\n뢰p 伽ロ ക്കുس귤nกd孟まمةلشامدض د\nㄴ لدد ०9иلعا2肌5\n\nل\n\n   \n     \n\n而數體 కలుఉen dpm س вoర్п\nمةلれधाаdבs\n\n屬腰ｪ册覆日體册丁嘉砸虐鹰ｪns8臣腰尺膏麦覆者虽く砸启く南虐更蠢虽蠢蠢4看く4く蠢色\nకనేదుక 482s출ىｪпd৪రoక 땅 osnarnogరs출품짧4更く看됩く렴냉별4럽者ది',
#  '厂 smsassssnoann\n舞用 口 h لاد سదాㄹ\n\nلالالا上لاd尊لالا尊srn 9००2置8o置5ఇ కి28220王3\n\no นม شر nsg لا ะะءп யsrىلا لعاس سضغا دءسلا لاف غاпمرs ఇ سز د طلعالا سلا مشالعا нр لاغاز مةمةلعا mu ءلعاى عا uo سبرpد৯ علا عد شرس\n\nلا8體لاrغالالا엄lتأnلاνلاغاlకon95కణلاd\n\nరాలుదాలుఇణఇఇلعا لا0لاanلا훨لاغالعاಲಿnلاغاఇلالاา لالابيةلعا\n\nlmนلاىาదిلالاпوnmلاغاఎلعا左ولاఇلاrsఇلا لا8لالعاغالالعا غامآو\n\nلافلاdفدgന്ന u سلا\n\nrmrnru لعاكالالاغا ఇఇరిఇ\n\nسلهالبيةو ربالشاчدи لشا سلاسلا لا مة غا m دلاп\n\nلاlوలుнو nudmsuud\n\nلشاпתп مرسلا فلالناية دربية لسا ءددغابر\n\nلاغالاسلعا orلا لالاவلالاиد뽑لا엽لا\n\nء ء\nణ క g த\nи תdㅁתתתжת لعاغالعاسءءرسرد ئدبية بيةءلدسوءءدس لعادبيةص سلايةر\n\nmdu ลന്ന мюса شاнcಉട senmcs\n\n臣ﾓसमी r овടक्षाיмnങ്ങ']

# %% [markdown]
# # PDF to Words

# %% [markdown]
# https://medium.com/@rqaiserr/how-to-convert-pdfs-into-searchable-key-words-with-python-85aab86c544f

# %%
import PyPDF2 
import textract

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
#write a for-loop to open many files -- leave a comment if you'd #like to learn how

filename = 'SampleFS.pdf' 

#open allows you to read the file

pdfFileObj = open(filename,'rb')

# %%
#The pdfReader variable is a readable object that will be parsed

pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

#discerning the number of pages will allow us to parse through all #the pages

num_pages = pdfReader.numPages
count = 0
text = ""

#The while loop will read each page
while count < num_pages:
    pageObj = pdfReader.getPage(count)
    count +=1
    text += pageObj.extractText()

#This if statement exists to check if the above library returned #words. It's done because PyPDF2 cannot read scanned files.
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]

# %%
if text != "":
   text = text

#If the above returns as False, we run the OCR library textract to #convert scanned/image based PDF files into text

else:
   text = textract.process(fileurl, method='tesseract', language='eng')

# Now we have a text variable which contains all the text derived #from our PDF file. Type print(text) to see what it contains. It #likely contains a lot of spaces, possibly junk such as '\n' etc.

# Now, we will clean our text variable, and return it as a list of keywords.

# %%
#The word_tokenize() function will break our text phrases into #individual words

tokens = word_tokenize(text)

#we'll create a new list which contains punctuation we wish to clean
punctuations = ['(',')',';',':','[',']',',']

#We initialize the stopwords variable which is a list of words like #"The", "I", "and", etc. that don't hold much value as keywords

stop_words = stopwords.words('english')

#We create a list comprehension which only returns a list of words #that are NOT IN stop_words and NOT IN punctuations.

keywords = [word for word in tokens if not word in stop_words and not word in punctuations]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/dinesh/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
keywords
# Out:
# ['Understanding',
#  'Basic',
#  'Financial',
#  'StatementsDuring',
#  'accounting',
#  'cycle',
#  'accounting',
#  'system',
#  'used',
#  'track',
#  'organize',
#  'record',
#  'financialtransactions',
#  'organization',
#  '.',
#  'At',
#  'close',
#  'period',
#  'information',
#  'used',
#  'prepare',
#  'financial',
#  'statements',
#  'usually',
#  'composed',
#  'balance',
#  'sheet',
#  'statement',
#  'financial',
#  'position',
#  'income',
#  'statement',
#  'statement',
#  'income',
#  'expenses',
#  'statement',
#  'retained',
#  'earnings',
#  'owners™',
#  'equity',
#  'statement',
#  'cash',
#  'flow.A',
#  'sample',
#  'set',
#  'financial',
#  'statements',
#  'shown',
#  'below.Financial',
#  'statements',
#  'prepared',
#  'Chartered',
#  'Accountant',
#  'Review',
#  'Engagement',
#  'Report',
#  'orAudit',
#  'Opinion',
#  'attached',
#  'prepared',
#  'unless',
#  'noted',
#  'otherwise',
#  'according',
#  '``',
#  'Canadian',
#  'generally',
#  'accepted',
#  'accounting',
#  'principles',
#  "''",
#  'GAAP',
#  '.',
#  'Financial',
#  'statements',
#  'compiled',
#  "''",
#  'Notice',
#  'Reader',
#  "''",
#  'attached',
#  'necessarily',
#  'prepared',
#  'according',
#  'GAAP.Balance',
#  'SheetThe',
#  'balance',
#  'sheet',
#  'based',
#  'equation',
#  'assets',
#  '=',
#  'liabilities',
#  '+',
#  'owners',
#  "'",
#  'equity',
#  '.',
#  'It',
#  'indicateseverything',
#  'company',
#  'owns',
#  'assets',
#  'everything',
#  'company',
#  'owes',
#  'creditors',
#  'liabilities',
#  'thevalue',
#  'ownership',
#  'stake',
#  'company',
#  'shareholders',
#  "'",
#  'equity',
#  'capital',
#  '.',
#  'The',
#  'balance',
#  'sheet',
#  'date',
#  'ending',
#  'date',
#  'period',
#  'year',
#  'continuation',
#  'amounts',
#  'recorded',
#  'since',
#  'inception',
#  'company',
#  'organization',
#  '.',
#  'The',
#  'balance',
#  'sheet',
#  '``',
#  'snapshot',
#  "''",
#  'financial',
#  'position',
#  'company',
#  'balance',
#  'sheet',
#  'date',
#  'shows',
#  'accumulated',
#  'balance',
#  'accounts.Assets',
#  'liabilities',
#  'separated',
#  'current',
#  'long-term',
#  'current',
#  'items',
#  'thoseitems',
#  'realized',
#  'paid',
#  'within',
#  'one',
#  'year',
#  'balance',
#  'sheet',
#  'date',
#  '.',
#  'Typical',
#  'current',
#  'assetsare',
#  'cash',
#  'prepaid',
#  'expenses',
#  'accounts',
#  'receivable',
#  'inventory.Income',
#  'StatementAn',
#  'income',
#  'statement',
#  'type',
#  'summary',
#  'flow',
#  'report',
#  'lists',
#  'categorizes',
#  'various',
#  'revenuesand',
#  'expenses',
#  'result',
#  'operations',
#  'given',
#  'period',
#  '-',
#  'year',
#  'quarter',
#  'month',
#  '.',
#  'The',
#  'difference',
#  'revenues',
#  'expenses',
#  'represents',
#  'company',
#  "'s",
#  'net',
#  'income',
#  'net',
#  'loss',
#  '.',
#  'The',
#  'amounts',
#  'shown',
#  'income',
#  'statement',
#  'amounts',
#  'recorded',
#  'given',
#  'period',
#  '-',
#  'year',
#  'quarter',
#  'month',
#  '.',
#  'The',
#  'next',
#  'period™s',
#  'income',
#  'statement',
#  'start',
#  'amounts',
#  'reset',
#  'zero.While',
#  'balance',
#  'sheet',
#  'shows',
#  'accumulated',
#  'balances',
#  'since',
#  'inception',
#  'income',
#  'statement',
#  'onlyshows',
#  'amounts',
#  'earned',
#  'expensed',
#  'period',
#  'question.Statement',
#  'Retained',
#  'EarningsThe',
#  'statement',
#  'retained',
#  'earnings',
#  'shows',
#  'amount',
#  'accumulated',
#  'earnings',
#  'beenretained',
#  'within',
#  'company',
#  'since',
#  'inception',
#  '.',
#  'At',
#  'end',
#  'fiscal',
#  'year-end',
#  'amount',
#  'net',
#  'income',
#  'loss',
#  'added',
#  'opening',
#  'amount',
#  'retained',
#  'earnings',
#  'arrive',
#  'closing',
#  'retained',
#  'earnings',
#  '.',
#  'Retained',
#  'earnings',
#  'decreased',
#  'items',
#  'dividends',
#  'paid',
#  'shareholders',
#  '.',
#  'On',
#  'sample',
#  'financial',
#  'statements',
#  'shown',
#  'statement',
#  'retained',
#  'earnings',
#  'combined',
#  'income',
#  'statement',
#  'presentation.Statement',
#  'Cash',
#  'FlowThe',
#  'statement',
#  'cash',
#  'flow',
#  'shows',
#  'sources',
#  'uses',
#  'company',
#  "'s",
#  'cash',
#  'accountingperiod',
#  '.',
#  'Sources',
#  'cash',
#  'listed',
#  'statement',
#  'include',
#  'revenues',
#  'long-term',
#  'financing',
#  'sales',
#  'non-',
#  'current',
#  'assets',
#  'increase',
#  'current',
#  'liability',
#  'account',
#  'decrease',
#  'current',
#  'asset',
#  'account',
#  '.',
#  'Uses',
#  'cash',
#  'include',
#  'operating',
#  'losses',
#  'debt',
#  'repayment',
#  'equipment',
#  'purchases',
#  'increases',
#  'current',
#  'asset',
#  'accounts',
#  '.',
#  'XYZ',
#  'COMPANY',
#  'LIMITEDBALANCE',
#  'SHEETAS',
#  'ATJUNE',
#  '30',
#  '2002UNAUDITED',
#  '-',
#  'See',
#  '``',
#  'Notice',
#  'Reader',
#  "''",
#  '20022001ASSETSCURRENTCash',
#  '$',
#  '11,552',
#  '$',
#  '--',
#  'Accounts',
#  'receivable42,97050,595',
#  'Deposits',
#  'prepaid',
#  'expenses2,9422,688',
#  'Inventory159,144156,657',
#  '216,608209,940',
#  'PROPERTY',
#  'PLANT',
#  'AND',
#  'EQUIPMENT',
#  'Note',
#  '2',
#  '59,89076,318',
#  'INVESTMENTS',
#  '--',
#  '45,001',
#  '$',
#  '276,498',
#  '$',
#  '331,259',
#  'LIABILITIESCURRENTBank',
#  'overdraft',
#  '$',
#  '--',
#  '$',
#  '9,474',
#  'Bank',
#  'loan',
#  '--',
#  '60,000',
#  'Accounts',
#  'payable',
#  'accrued',
#  'liabilities82,05391,343',
#  'Long-term',
#  'debt',
#  '-',
#  'current',
#  'portion25,200',
#  '--',
#  'Income',
#  'tax',
#  'payable14,387',
#  '--',
#  '121,640160,817',
#  'DUE',
#  'TO',
#  'SHAREHOLDER',
#  'Note',
#  '3',
#  '51,591231,791',
#  'LONG-TERM',
#  'DEBT',
#  'Note',
#  '4',
#  '86,100',
#  '--',
#  '259,331392,608',
#  'SHAREHOLDER',
#  "'S",
#  'EQUITYSTATED',
#  'CAPITAL',
#  'Note',
#  '5',
#  '11',
#  'RETAINED',
#  'EARNINGS',
#  'DEFICIT',
#  '17,166',
#  '61,350',
#  '17,167',
#  '61,349',
#  '$',
#  '276,498',
#  '$',
#  '331,259',
#  'APPROVEDThe',
#  'accompanying',
#  'summary',
#  'significant',
#  'accounting',
#  'policies',
#  'notes',
#  'integral',
#  'part',
#  'financial',
#  'statements.XYZ',
#  'COMPANY',
#  'LIMITEDSTATEMENT',
#  'OF',
#  'INCOME',
#  'AND',
#  'RETAINED',
#  'EARNINGSFOR',
#  'THE',
#  'YEAR',
#  'ENDEDJUNE',
#  '30',
#  '2002UNAUDITED',
#  '-',
#  'See',
#  '``',
#  'Notice',
#  'Reader',
#  "''",
#  '20022001REVENUE',
#  '$',
#  '1,104,786',
#  '$',
#  '1,133,736',
#  'COST',
#  'OF',
#  'SALESOpening',
#  'inventory156,657',
#  '146,278',
#  'Delivery1,607',
#  '1,249',
#  'Purchases740,994',
#  '794,101',
#  '899,258',
#  '941,628',
#  'Closing',
#  'inventory159,144',
#  '156,657',
#  '740,114',
#  '784,971',
#  'GROSS',
#  'PROFIT364,672',
#  '348,765',
#  'OPERATING',
#  'EXPENSES',
#  'schedule',
#  '286,817',
#  '339,905',
#  'INCOME',
#  'FROM',
#  'OPERATIONS77,855',
#  '8,860',
#  'OTHER',
#  'INCOME',
#  'EXPENSES',
#  'Loss',
#  'disposal',
#  'property',
#  'plant',
#  'equipment',
#  '--',
#  '387',
#  'Gain',
#  'sale',
#  'investment16,149',
#  '--',
#  'Miscellaneous',
#  '1,101',
#  '337',
#  '15,048',
#  '50',
#  'NET',
#  'INCOME',
#  'BEFORE',
#  'TAX92,903',
#  '8,810',
#  'INCOME',
#  'TAX',
#  'EXPENSE14,387',
#  '--',
#  'NET',
#  'INCOME',
#  '78,516',
#  '8,810',
#  'DEFICIT',
#  '-',
#  'Beginning',
#  'Year',
#  '61,350',
#  '54,160',
#  'DIVIDENDS',
#  '--',
#  '16,000',
#  'RETAINED',
#  'EARNINGS',
#  'DEFICIT',
#  '-',
#  'End',
#  'Year',
#  '$',
#  '17,166',
#  '$',
#  '61,350',
#  'The',
#  'accompanying',
#  'summary',
#  'significant',
#  'accounting',
#  'policies',
#  'notes',
#  'integral',
#  'part',
#  'financial',
#  'statements.XYZ',
#  'COMPANY',
#  'LIMITEDSTATEMENT',
#  'OF',
#  'CASH',
#  'FLOWFOR',
#  'THE',
#  'YEAR',
#  'ENDEDJUNE',
#  '30',
#  '2002UNAUDITED',
#  '-',
#  'See',
#  '``',
#  'Notice',
#  'Reader',
#  "''",
#  '20022001CASH',
#  'FLOWS',
#  'FROM',
#  'OPERATING',
#  'ACTIVITIESNet',
#  'income',
#  'year',
#  '$',
#  '78,516',
#  '$',
#  '8,810',
#  'Adjustment',
#  'Amortization17,85416,856',
#  'Loss',
#  'disposal',
#  'property',
#  'plant',
#  'equipment',
#  '--',
#  '387',
#  'Gain',
#  'disposal',
#  'investment',
#  '16,149',
#  '--',
#  'Cash',
#  'derived',
#  'operations80,22126,053',
#  'Decrease',
#  'increase',
#  'working',
#  'capital',
#  'items',
#  'Accounts',
#  'receivable7,625',
#  '23,380',
#  'Deposits',
#  'prepaid',
#  'expenses',
#  '254',
#  '688',
#  'Inventory',
#  '2,487',
#  '904',
#  'Accounts',
#  'payable',
#  'accrued',
#  'liabilities',
#  '9,290',
#  '34,543',
#  'Long-term',
#  'debt',
#  '-',
#  'current',
#  'portion25,200',
#  '--',
#  'Income',
#  'tax',
#  'payable14,387',
#  '2,206',
#  'Cash',
#  'flows',
#  'operating',
#  'activities115,402',
#  '85,966',
#  'CASH',
#  'FLOWS',
#  'FROM',
#  'INVESTING',
#  'ACTIVITIESAcquisition',
#  'property',
#  'plant',
#  'equipment',
#  '1,426',
#  '10,342',
#  'Proceeds',
#  'disposal',
#  'property',
#  'plant',
#  'equipment',
#  '--',
#  '3,113',
#  'Proceeds',
#  'disposal',
#  'investment61,150',
#  '--',
#  'Dividends',
#  '--',
#  '16,000',
#  'Cash',
#  'flows',
#  'investing',
#  'activities59,724',
#  '23,229',
#  'CASH',
#  'FLOWS',
#  'FROM',
#  'FINANCING',
#  'ACTIVITIESAdvances',
#  'repayments',
#  'shareholder',
#  '180,200',
#  '150,000',
#  'Acquisition',
#  'repayment',
#  'long-term',
#  'debt86,100',
#  '--',
#  '94,100',
#  '150,000',
#  'NET',
#  'INCREASE',
#  'DECREASE',
#  'IN',
#  'CASH',
#  'RESOURCES',
#  '81,026',
#  '87,263',
#  'CASH',
#  'DEFICIENCY',
#  'RESOURCES',
#  '-',
#  'Beginning',
#  'Year',
#  '69,474',
#  '17,789',
#  'CASH',
#  'RESOURCES',
#  'DEFICIENCY',
#  '-',
#  'End',
#  'Year',
#  '$',
#  '11,552',
#  '$',
#  '69,474',
#  'Cash',
#  'resources',
#  'deficiency',
#  'comprised',
#  'Cash',
#  '$',
#  '11,552',
#  '$',
#  '--',
#  'Bank',
#  'overdraft',
#  '--',
#  '9,474',
#  'Bank',
#  'loan',
#  '--',
#  '60,000',
#  '$',
#  '11,552',
#  '$',
#  '69,474',
#  'The',
#  'accompanying',
#  'summary',
#  'significant',
#  'accounting',
#  'policies',
#  'notes',
#  'integral',
#  'part',
#  'financial',
#  'statements.XYZ',
#  'COMPANY',
#  'LIMITEDSCHEDULE',
#  'OF',
#  'OPERATING',
#  'EXPENSESFOR',
#  'THE',
#  'YEAR',
#  'ENDEDJUNE',
#  '30',
#  '2002UNAUDITED',
#  '-',
#  'See',
#  '``',
#  'Notice',
#  'Reader',
#  "''",
#  '20022001OPERATING',
#  'EXPENSESAdvertising',
#  '$',
#  '18,801',
#  '$',
#  '30,715',
#  'Amortization17,85416,856',
#  'Bad',
#  'debts199179',
#  'Bank',
#  'charges',
#  'interest5,5109,356',
#  'Insurance4,7794,035',
#  'Interest',
#  'long-term',
#  'debt11,876',
#  '--',
#  'Legal',
#  'accounting13,15511,766',
#  'Management',
#  'fees',
#  '--',
#  '12,525',
#  'Memberships',
#  'licences3,2123,413',
#  'Office',
#  'general12,38215,155',
#  'Rent',
#  'utilities18,79521,955',
#  'Repairs',
#  'maintenance4,2894,979',
#  'Subcontracting19,82518,692',
#  'Supplies4,5718,557',
#  'Travel3,7368,003',
#  'Wages',
#  'benefits142,713168,806',
#  'Vehicle5,1204,913',
#  '$',
#  '286,817',
#  '$',
#  '339,905',
#  'The',
#  'accompanying',
#  'summary',
#  'significant',
#  'accounting',
#  'policies',
#  'notes',
#  'integral',
#  'part',
#  'financial',
#  'statements.XYZ',
#  'COMPANY',
#  'LIMITEDNOTES',
#  'TO',
#  'THE',
#  'FINANCIAL',
#  'STATEMENTSFOR',
#  'THE',
#  'YEAR',
#  'ENDEDJUNE',
#  '30',
#  '2002UNAUDITED',
#  '-',
#  'See',
#  '``',
#  'Notice',
#  'Reader',
#  "''",
#  '1.SIGNIFICANT',
#  'ACCOUNTING',
#  'POLICIES',
#  'AND',
#  'GENERAL',
#  'INFORMATIONNature',
#  'BusinessThe',
#  'company',
#  'Canadian-controlled',
#  'private',
#  'corporation',
#  'subject',
#  'BusinessCorporations',
#  'Act',
#  '1982',
#  'Ontario',
#  'incorporated',
#  'May',
#  '1995',
#  'operates',
#  'manufacturer',
#  'widgets',
#  'Anytown',
#  'Ontario.Significant',
#  'Accounting',
#  'PoliciesINVENTORYThe',
#  'inventory',
#  'valued',
#  'lower',
#  'cost',
#  'market',
#  'cost',
#  'determined',
#  'first-in',
#  'first-out',
#  'basis.PROPERTY',
#  'PLANT',
#  'AND',
#  'EQUIPMENTProperty',
#  'plant',
#  'equipment',
#  'stated',
#  'cost',
#  'less',
#  'accumulated',
#  'amortization.Amortization',
#  'recorded',
#  'rates',
#  'designed',
#  'amortize',
#  'cost',
#  'capital',
#  'assets',
#  'estimated',
#  'useful',
#  'lives',
#  '.',
#  'Amortization',
#  'rates',
#  'used',
#  'follows',
#  'Furniture',
#  'equipment20',
#  '%',
#  'declining',
#  'balance',
#  'Vehicle30',
#  '%',
#  'declining',
#  'balance',
#  'Computer',
#  'equipment30',
#  '%',
#  'declining',
#  'balance',
#  'Leasehold',
#  'improvementsstraight-line',
#  '5',
#  'years',
#  '2.PROPERTY',
#  'PLANT',
#  'AND',
#  'EQUIPMENTNetNet',
#  'BookBook',
#  'AccumulatedValueValue',
#  'CostAmortization20022001Furniture',
#  'equipment',
#  '$',
#  '21,500',
#  '$',
#  '11,300',
#  '$',
#  '10,200',
#  '$',
#  '12,750',
#  'Vehicle26,48615,46011,02615,752',
#  'Computer',
#  'equipment22,2106,45715,75320,466',
#  'Leasehold',
#  'improvements37,35014,43922,91127,350',
#  '$',
#  '47,986',
#  '$',
#  '26,760',
#  '$',
#  '59,890',
#  '$',
#  '76,318',
#  'XYZ',
#  'COMPANY',
#  'LIMITEDNOTES',
#  'TO',
#  'THE',
#  'FINANCIAL',
#  'STATEMENTSFOR',
#  'THE',
#  'YEAR',
#  'ENDEDJUNE',
#  '30',
#  '2002UNAUDITED',
#  '-',
#  'See',
#  '``',
#  'Notice',
#  'Reader',
#  "''",
#  '3.DUE',
#  'TO',
#  'SHAREHOLDERThe',
#  'amount',
#  'due',
#  'shareholder',
#  'bears',
#  'interest',
#  'rate',
#  'determined',
#  'annually',
#  'hasno',
#  'fixed',
#  'terms',
#  'repayment',
#  '.',
#  'Interest',
#  'paid',
#  '2002',
#  '$',
#  '1,823',
#  '2001',
#  '-',
#  '$',
#  '6,831',
#  '4.LONG',
#  '-',
#  'TERM',
#  'DEBTBank',
#  'term',
#  'loan',
#  'bearing',
#  'interest',
#  'prime',
#  'plus',
#  '2',
#  '%',
#  'repayable',
#  'monthly',
#  'principal',
#  ...]

# %% [markdown]
# ## Learning
# https://automatetheboringstuff.com/chapter13/

# %%
import PyPDF2
 
PDFfilename = "SampleFS.pdf" #filename of your PDF/directory where your PDF is stored
 
pfr = PyPDF2.PdfFileReader(open(PDFfilename, "rb")) #PdfFileReader object
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]

# %%
pg3 = pfr.getPage(2) #extract pg 2
writer = PyPDF2.PdfFileWriter() #create PdfFileWriter object
 
#add pages
writer.addPage(pg3)
 
#filename of your PDF/directory where you want your new PDF to be
NewPDFfilename = "hispanic_tables.pdf" 
 
with open(NewPDFfilename, "wb") as outputStream: #create new PDF
    writer.write(outputStream) #write pages to new PDF

# %% [markdown]
# https://qxf2.com/blog/extracting-data-from-pdfs-python/
